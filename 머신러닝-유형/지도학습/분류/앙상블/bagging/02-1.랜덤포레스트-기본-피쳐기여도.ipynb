# %% [markdown]
# https://velog.io/@kungsboy/%EB%9E%9C%EB%8D%A4%ED%8F%AC%EB%A0%88%EC%8A%A4%ED%8A%B8-%ED%94%BC%EC%B3%90-%EC%A4%91%EC%9A%94%EB%8F%84

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

df = pd.DataFrame({
    "study":[1,2,3,4,5,6,7,8],
    "sleep":[8,7,7,6,6,5,5,4],
    "homework":[1,2,3,4,5,6,7,8],
    "pass":[0,0,0,0,1,1,1,1]
})

X = df[["study","sleep","homework"]]
y = df["pass"]

model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

model.fit(X,y)

print(model.feature_importances_)

importance = pd.Series(
    model.feature_importances_,
    index=X.columns
)

print(importance)
# Out:
# [0.38970635 0.30146825 0.3088254 ]
# study       0.389706
# sleep       0.301468
# homework    0.308825
# dtype: float64

# %%
importance.sort_values().plot.barh()
# Out:
# <Axes: >
