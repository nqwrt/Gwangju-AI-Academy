# %%
store = {}

def get_session_history(session_id):
    if session_id not in store:
        store[session_id] = []
    return store[session_id]


def chat(session_id, message):
    history = get_session_history(session_id)
    
    # 대화 저장
    history.append(f"사용자: {message}")
    
    # AI 응답 (가짜)
    response = f"AI: '{message}'에 대한 답변입니다"
    history.append(response)
    
    return response

# 사용자 1
chat("user1", "안녕")
chat("user1", "오늘 날씨 어때?")

# 사용자 2
#chat("user2", "안녕")

print(store)
# Out:
# {'user1': ['사용자: 안녕', "AI: '안녕'에 대한 답변입니다", '사용자: 오늘 날씨 어때?', "AI: '오늘 날씨 어때?'에 대한 답변입니다"]}
