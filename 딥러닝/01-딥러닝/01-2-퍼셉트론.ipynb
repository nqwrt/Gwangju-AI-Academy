# %% [markdown]
# https://www.youtube.com/watch?v=M7BQXAL6MjQ  고등학교 수학만 알면 따라할 수 있는 인공지능, 머신러닝, 딥러닝 38

# %%
from sklearn.linear_model import Perceptron
import numpy as np

X=np.array([[0],[1]])

y=[0,1]

model=Perceptron()
model.fit(X,y)

print(model.predict([[0]]))
print(model.predict([[1]]))
# Out:
# [0]
# [1]

# %%
# XOR 실패 실험

# 드디어 원본 코드

from sklearn.linear_model import Perceptron
import numpy as np

X = np.array([
[0,0],
[0,1],
[1,0],
[1,1]
])

y=[0,1,1,0]

model = Perceptron()
model.fit(X,y)

print(model.predict(X))

# 원래 정답(XOR)은:
# y=[0,1,1,0]
# 정답을 제대로 맞추지 못하고 있음

# [0 0 0 0]
# Out:
# [0 0 0 0]

# %%
import matplotlib.pyplot as plt

plt.scatter(0,0,c="blue")
plt.scatter(0,1,c="red")
plt.scatter(1,0,c="red")
plt.scatter(1,1,c="blue")

plt.grid()
plt.show()

# %%
# 문제 해결
from sklearn.neural_network import MLPClassifier

# 다층 퍼셉트론
model = MLPClassifier( 
    hidden_layer_sizes=(4,),
    max_iter=3000
)

model.fit(X,y)

print(model.predict(X))
# Out:
# [0 1 1 0]

# %%
# !pip install tensorflow

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 데이터
X=np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
], dtype="float32")


y=np.array([
    [0],
    [1],
    [1],
    [0]
], dtype="float32")


# 모델 생성
model = Sequential([
        Dense(4,input_shape=(2,),activation="relu"),
        Dense(1,activation="sigmoid")
    ])

# 학습 설정
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
# 학습
model.fit(X,y,epochs=3000,verbose=0)
# 예측
pred=model.predict(X)

print(pred)
print((pred>0.5).astype(int))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [[0.12215385]
#  [0.8793392 ]
#  [0.87949616]
#  [0.12018551]]
# [[0]
#  [1]
#  [1]
#  [0]]
